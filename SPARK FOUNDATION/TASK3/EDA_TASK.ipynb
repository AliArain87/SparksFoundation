# %% [markdown]
# ### ALI HASNAIN
# ### SPARKS FOUNDATION-GRIPS-DATA SCIENCE AND BUSINESS ANALYTICS
# ### TASK-3
# ### EDA ON SAMPLE SUPERSTORE DATASET

# %% [markdown]
# ## IMPORTING THE LIBRARIES

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## LOAD THE DATASET

# %%
data= pd.read_csv('D:\Big Data\SPARK FOUNDATION\SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## CHECKING 1ST FIVE VALUES OF DATASET

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ## CHECKING LAST FIVE VALUES OF DATASET

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# ### INFO TELL US THE DATA TYPE DETAILS OF EVERY COLUMN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# # DESCRIBE THE NUMERIC VALUE WITH MEAN, MEDIAN, MODE ETC

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # CHECKING THE NUMBER OF VALUES

# %%
data.size
# Out:
# 129922

# %% [markdown]
# # CHECKING THE NUMBER OF ROWS AND COLUMNS

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # CHECKING THE NULL VALUES

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # CHECKING THE UNIQUE VALUES IN EVERY COLUMN

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # LET'S BEGIN WITH EDA

# %%
sns.scatterplot(x='Sales', y='Profit', data=data)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# PROFIT IS MORE THAN SELL BUT THERE ARE SOME AREAS, WHERE PROFIT IS NOT INCREASING LIKE SHOWING IN -VE VALUES

# %%
corr = data.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# HERE WE CAN SAY THAT:
# ~ PROFIT AND DISCOUNT ARE NEGATIVELY CORRELATED
# ~ SALES AND PROFIT ARE CORRELATED MODERATELY - MEANS THAT IS GOING TO CHANGE IF WE CHANGE ANY ONE OF THEM

# %%
sns.pairplot(data.corr())

# %%
sns.pairplot(data, hue='Category')

# %%
px.histogram(data, x='Category', title='COUNT VALUES OF CATEGORY')

# %%
px.histogram(data, x='Segment', title='COUNT VALUES OF SEGMENTS')

# %%
px.histogram(data, x='Ship Mode', title='COUNT VALUES OF SHIP MODE')

# %%
px.histogram(data, x='Region', title='COUNT VALUES OF REGION')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Sub-Category', data=data)
plt.title('Sub-Category', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Quantity', data=data)
plt.title('COUNT BY QUANTITY VISE',fontsize=23)
# Out:
# Text(0.5, 1.0, 'COUNT BY QUANTITY VISE')

# %% [markdown]
# # STATEWISE CHECKING

# %%
    data['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
data1= data['State'].value_counts()
data1
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
px.scatter(data1, title='STATEWISE DEALING')

# %% [markdown]
# ### HERE, I CAN CONCLUDE THAT THE TOP 3 STATES WHERE THE DEALS ARE HIGHEST ARE:
# 1) CALIFORNIA
# 2) NEW YORK
# 3) TEXAS

# %% [markdown]
# ### AND LOWEST DEAL CONTAIN IN STATE : WYOMING
# AS CLEAR FROM GRAPH

# %% [markdown]
# # CITYWISE CHECKING THE DEALS

# %%
city= data['City'].value_counts()
city=city.head(40)
city
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Arlington         60
# San Antonio       59
# Miami             57
# Louisville        57
# Rochester         53
# Charlotte         52
# Henderson         51
# Lakewood          49
# Lancaster         46
# Fairfield         45
# Milwaukee         45
# Denver            44
# Lawrence          44
# Baltimore         43
# Cleveland         42
# Pasadena          42
# San Jose          42
# Fayetteville      41
# Salem             40
# Atlanta           39
# Name: City, dtype: int64

# %%
px.bar(city, title='Citywise Analysis')

# %% [markdown]
# # TOP 3 CITIES ARE:
# 1) NEW YORK CITY
# 2) LOS ANGELES
# 3) PHILADELPHIA

# %%
px.bar(data.head(20), x='City', y='Profit',color='State', title='STATEWISE+CITYWISE PROFIT')

# %%
px.bar(data.head(20), x='State', y='Profit',color='Discount', title='PROFIT VS DISCOUNT')

# %% [markdown]
# # MY CONCLUSION IS:

# %% [markdown]
# ##### ~ Where the profit is high so there is no discount.
# ##### ~ If discount is given so profit is going to decrease.
# ##### ~ The West-Region has highest value.
# ##### ~ Top 3 states which have highest deals are (Califonia, New york, Texas)
# ##### ~ Top 3 states which have highest deals are (New york City, Los Angeles, Philadelphia)
# ##### ~ Wyoming is the state where lowest no: of deals are done
